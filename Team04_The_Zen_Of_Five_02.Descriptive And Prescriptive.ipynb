# %%
# DESCRIPTIVE QUESTIONS

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#For the EDA (Exploratory Data Analysis)

# %%
df_master = pd.read_csv("cardiac_failure/cf_master_dataset.csv")

# %%
print("Shape:", df_master.shape)
# Out:
# Shape: (2008, 200)

# %%
df_master.head()
# Out:
#    inpatient_number  gender  weight  height        bmi      occupation agecat  \
# 0            827040  Female    50.0    1.45  23.781213     Unspecified  69-79
# 1            857781    Male    50.0    1.64  18.590125  Urban Resident  69-79
# 2            743087  Female    51.0    1.63  19.195303  Urban Resident  69-79
# 3            866418    Male    70.0    1.70  24.221453          Farmer  59-69
# 4            775928    Male    65.0    1.70  22.491349  Urban Resident  69-79
#
#    flag_invalid_height  flag_invalid_weight bmi_category  ...  \
# 0                False                False       Normal  ...
# 1                False                False       Normal  ...
# 2                False                False       Normal  ...
# 3                False                False       Normal  ...
# 4                False                False       Normal  ...
#
#    congestive_heart_failure  peripheral_vascular_disease  \
# 0                         1                            0
# ...

# %%
df_master.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2008 entries, 0 to 2007
# Columns: 200 entries, inpatient_number to tricuspid_valve_return_pressure
# dtypes: bool(2), float64(148), int64(35), object(15)
# memory usage: 3.0+ MB

# %%
df_master.dtypes
# Out:
# inpatient_number                     int64
# gender                              object
# weight                             float64
# height                             float64
# bmi                                float64
#                                     ...
# mitral_valve_ems                   float64
# mitral_valve_ams                   float64
# ea                                 float64
# tricuspid_valve_return_velocity    float64
# tricuspid_valve_return_pressure    float64
# Length: 200, dtype: object

# %%
missing = df_master.isnull().sum().sort_values(ascending=False)

missing[missing > 0]
# Out:
# cholinesterase                           2008
# respiratory_support                      1966
# time_of_death__days_from_admission       1964
# homocysteine                             1862
# lipoprotein                              1832
#                                          ...
# rx_digoxin_tablet                           1
# rx_furosemide_tablet                        1
# rx_warfarin_sodium_tablet                   1
# rx_enoxaparin_sodium_injection              1
# rx_dobutamine_hydrochloride_injection       1
# Length: 148, dtype: int64

# %%
missing_percent = (df_master.isnull().sum() / len(df_master) * 100).sort_values(ascending=False)

missing_summary = pd.DataFrame({
    "Missing_Count": df_master.isnull().sum(),
    "Missing_Percentage": missing_percent
})
print(missing_percent)
# Out:
# cholinesterase                        100.000000
# respiratory_support                    97.908367
# time_of_death__days_from_admission     97.808765
# homocysteine                           92.729084
# lipoprotein                            91.235060
#                                          ...
# movement                                0.000000
# consciousness                           0.000000
# gcs                                     0.000000
# destinationdischarge                    0.000000
# inpatient_number                        0.000000
# Length: 200, dtype: float64

# %%
#1. What's the gender split of the cohort?
#Insight: 57.9% female, 42.1% male. | Tableau: pie chart on gender.


print(df_master['gender'].value_counts(normalize=True).round(3))
# Out:
# gender
# Female    0.579
# Male      0.421
# Name: proportion, dtype: float64

# %%
# Categorical & Demographic Distributions
print("\n" + "="*60)
print("2. DEMOGRAPHICS & CLINICAL CATEGORICAL BREAKDOWN")
print("="*60)
    
cat_cols = ['gender', 'agecat', 'bmi_category', 'admission_way', 'outcome_during_hospitalization']
for col in cat_cols:
    if col in df_master.columns:
        counts = df_master[col].value_counts()
        props = df_masater[col].value_counts(normalize=True) * 100
        summary = pd.DataFrame({'Count': counts, 'Percentage (%)': props.round(2)})
        print(f"\n--- {col.upper()} ---")
        print(summary)

    # Continuous Biomarkers & Vitals Analysis
print("\n" + "="*60)
print("3. CONTINUOUS LABS & VITALS SUMMARY STATISTICS")
print("="*60)
    
key_vitals_labs = [
'body_temperature', 'pulse', 'respiration', 'systolic_blood_pressure',
'diastolic_blood_pressure', 'map_value', 'brain_natriuretic_peptide',
'creatinine_enzymatic_method', 'urea', 'high_sensitivity_troponin', 
'd_dimer', 'lvef', 'cci_score', 'total_prescriptions_count'
]
    
present_labs = [c for c in key_vitals_labs if c in df.columns]
num_summary = df[present_labs].describe().T[['count', 'mean', 'std', 'min', '50%', 'max']]
num_summary.rename(columns={'50%': 'median'}, inplace=True)
    
num_summary.to_csv(f"{output_dir}/vitals_labs_summary.csv")
print(num_summary.round(2))
print(f"\n• Summary statistics saved to: '{output_dir}/vitals_labs_summary.csv'")

#Outcome & Readmission Rates
print("\n" + "="*60)
print("4. CLINICAL OUTCOMES & READMISSION RATES")
print("="*60)
    
readm_cols = ['re_admission_within_28_days', 're_admission_within_3_months', 're_admission_within_6_months',
                  'death_within_28_days', 'death_within_6_months']
    
for r in readm_cols:
    if r in df.columns:
        rate = df[r].mean() * 100
        print(f"• {r.replace('_', ' ').title()}: {rate:.2f}%")

    # Dashboard Visualizations
print("\n" + "="*60)
print("5. GENERATING VISUAL EDA DASHBOARDS")
print("="*60)
# Out:
# ...
# 2. DEMOGRAPHICS & CLINICAL CATEGORICAL BREAKDOWN
# ...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 10
#       8 if col in df_master.columns:
#       9     counts = df_master[col].value_counts()
# ---> 10     props = df_masater[col].value_counts(normalize=True) * 100
#      11     summary = pd.DataFrame({'Count': counts, 'Percentage (%)': props.round(2)})
#      12     print(f"\n--- {col.upper()} ---")
#
# NameError: name 'df_masater' is not defined

# %%
#2. What age bands make up the cohort?
#Insight: 69–79 (35.6%) and 79–89 (32.2%) dominate — this is an elderly cohort. | Tableau: bar chart, agecat sorted.


print(df_master['agecat'].value_counts(normalize=True).round(3).sort_index())
# Out:
# agecat
# 21-29     0.002
# 29-39     0.006
# 39-49     0.028
# 49-59     0.053
# 59-69     0.183
# 69-79     0.356
# 79-89     0.322
# 89-110    0.050
# Name: proportion, dtype: float64

# %%
#3. What type of heart failure is most common?
#Insight: 73.7% Both-sided, 23.8% Left, only 2.5% Right-only. | Tableau: stacked bar, type_of_heart_failure.

print(df_master['type_of_heart_failure'].value_counts(normalize=True).round(3))
# Out:
# type_of_heart_failure
# Both     0.737
# Left     0.238
# Right    0.025
# Name: proportion, dtype: float64
